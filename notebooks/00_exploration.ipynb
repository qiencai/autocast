# %%
from autoemulate.simulations.advection_diffusion import AdvectionDiffusion

sim = AdvectionDiffusion(return_timeseries=True, log_level="error")
train_data = sim.forward_samples_spatiotemporal(40)
valid_data = sim.forward_samples_spatiotemporal(10)
test_data = sim.forward_samples_spatiotemporal(10)

combined_data = {
    "train": train_data,
    "valid": valid_data,
    "test": test_data,
}

# %%
from auto_cast.data.datamodule import SpatioTemporalDataModule

# Read combined data into datamodule
datamodule = SpatioTemporalDataModule(
    data=combined_data, data_path=None, n_steps_input=4, n_steps_output=1, batch_size=16
)

# %%
# Example batch
batch = next(iter(datamodule.train_dataloader()))

# %%
#TODO: make an example FNO processor model and train it
from auto_cast.processors.fno import FNOProcessor

model = FNOProcessor(in_channels=1, out_channels=1, n_modes=(16,), hidden_channels=64)

# %%
import lightning as L

# Run trainer
trainer = L.Trainer(max_epochs=5, accelerator="cpu", log_every_n_steps=20)
trainer.fit(model, datamodule.train_dataloader(), datamodule.val_dataloader())

# %%
# Run the evaluation
trainer.test(model, datamodule.test_dataloader())
